# %% [markdown]
# ![Screen%20Shot%202022-11-04%20at%202.59.46%20PM.png](attachment:Screen%20Shot%202022-11-04%20at%202.59.46%20PM.png)

# %%
pip install translate
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 22.3 is available.
# You should consider upgrading via the '/Users/roja/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from translate import Translator

spanishtrans = Translator(from_lang="English", to_lang="Spanish")
text = spanishtrans.translate("Good Morning")
print(text)
# Out:
# Buenos días

# %% [markdown]
# ![Spanish.png](attachment:Spanish.png)

# %%
from translate import Translator

chinesetrans = Translator(from_lang="English", to_lang="Chinese")
text = chinesetrans.translate("Good Morning")
print(text)
# Out:
# 早上好

# %% [markdown]
# ![Chinese.png](attachment:Chinese.png)

# %%
from translate import Translator

telugutrans = Translator(from_lang="English", to_lang="Telugu")
text = telugutrans.translate("Good Morning")
print(text)
# Out:
# శుభోదయం

# %% [markdown]
# ![Telugu.png](attachment:Telugu.png)

# %%
from translate import Translator

frenchtrans = Translator(from_lang="English", to_lang="French")
translation = frenchtrans.translate("Good Morning")
print(translation)
# Out:
# Bon Matin

# %% [markdown]
# ![Screen%20Shot%202022-11-04%20at%202.28.08%20PM.png](attachment:Screen%20Shot%202022-11-04%20at%202.28.08%20PM.png)

# %% [markdown]
# ![French.png](attachment:French.png)

# %%
from translate import Translator

italiantrans = Translator(from_lang="English", to_lang="Italian")
text = italiantrans.translate("Good Morning")
print(text)
# Out:
# Buongiorno

# %% [markdown]
# ![Italian.png](attachment:Italian.png)

# %% [markdown]
# ### Report:
#
#
# Problem statement: In any programming language translate the text from one language to another.
#
# Input data: Languages and the phrase you want to translate
#
# Methods: Using the python module "Translator" and installing the requirements befor ethe code run.
#
# Code: It is same as above.
#
# Results: Got a translated text "from specified language" to "to specified language".
# Also, included google tranlsated text as part of verification.
#
# Note that French language has two different text when you translate. Both are correct.

# %% [markdown]
# ![Screen%20Shot%202022-11-04%20at%203.03.44%20PM.png](attachment:Screen%20Shot%202022-11-04%20at%203.03.44%20PM.png)
